# %%
#radial basis functioon important

# %%
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_circles
#here we creat daata for svm
x, y = make_circles(200, factor=.1, noise=.1)

# %%
import pandas as pd
X=pd.DataFrame(x)

# %%
x_train=x[1:140]
y_train=y[1:140]
x_test=x[140:]
y_test=y[140:]

# %%
plt.scatter(X.iloc[:,0],X.iloc[:,1],c=y)
plt.xlabel('light Frequency',fontsize=18)
plt.ylabel('light Amplitude',fontsize=18)
plt.show()

# %%
from sklearn.svm import SVC

# %%
#C=1E6 for tunning paramiter (adjustting parameter)or cost function for making model more generic which reduse overfitting of model
#model=clf
clf=SVC(kernel='rbf',C=1E6)#kernel=linear for linear regression
clf.fit(x_train, y_train)
# Out:
# D:\anaconda\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1000000.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
from sklearn.metrics import accuracy_score
predicted_SVC=clf.predict(x_test)
accuracy=round(accuracy_score(predicted_SVC,y_test)*100,2)
print('Accuracy of SVC model is',accuracy,'%')
# Out:
# Accuracy of SVC model is 100.0 %
